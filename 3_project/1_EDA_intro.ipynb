# %% [markdown]
# Exploratory Data Analysis
# Roles to Explore:

# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df["job_skills"].apply(lambda Skill_list: ast.literal_eval(Skill_list) if pd.notna(Skill_list) else Skill_list)

# %%
df_us = df[(df['job_title_short']== "Data Analyst") & (df['job_country']=="United States")]
df_us
# Out:
#        job_title_short                                     job_title  \
# 36        Data Analyst                                  Data Analyst
# 68        Data Analyst                     Sr. Research Data Analyst
# 73        Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79        Data Analyst                    Data Analyst/Report Writer
# 93        Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# ...                ...                                           ...
# 785603    Data Analyst                           Junior Data Analyst
# 785626    Data Analyst                    Data Acquisition Associate
# 785685    Data Analyst                                  Data Analyst
# 785703    Data Analyst       Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst     Expert Business Data Analyst - Now Hiring
#
#             job_location               job_via job_schedule_type  \
# 36        Des Moines, IA       via Trabajo.org         Full-time
# ...

# %%
df_us_plot = df_us["job_location"].value_counts().head(10)
df_us_plot
# Out:
# job_location
# Anywhere           5106
# New York, NY       3035
# Atlanta, GA        2741
# Chicago, IL        2337
# Austin, TX         1919
# Dallas, TX         1862
# Washington, DC     1592
# Charlotte, NC      1433
# Tampa, FL          1431
# Los Angeles, CA    1328
# Name: count, dtype: int64

# %%
df_us_plot = df_us_plot.to_frame() #to use seaborn convert to datafrmae
df_us_plot
# Out:
#                  count
# job_location
# Anywhere          5106
# New York, NY      3035
# Atlanta, GA       2741
# Chicago, IL       2337
# Austin, TX        1919
# Dallas, TX        1862
# Washington, DC    1592
# Charlotte, NC     1433
# Tampa, FL         1431
# Los Angeles, CA   1328

# %%
df_us_plot
# Out:
#                  count
# job_location
# Anywhere          5106
# New York, NY      3035
# Atlanta, GA       2741
# Chicago, IL       2337
# Austin, TX        1919
# Dallas, TX        1862
# Washington, DC    1592
# Charlotte, NC     1433
# Tampa, FL         1431
# Los Angeles, CA   1328

# %%
sns.set_theme(style="ticks")
sns.barplot(data=df_us_plot,x="count",y="job_location",hue="count",palette="dark:b_r",legend=False)
plt.xlabel('No of jobs')
plt.ylabel('')
plt.title('job location count for data analysist in us')
sns.despine() #remove border around graph

# %% [markdown]
# Job Requirements

# %%
fig, ax = plt.subplots(1,3)
dict_coloumn = {
    "job_work_from_home": "Work From Home",
    "job_no_degree_mention": "No Degree Mention",
    "job_health_insurance": "Health Insurance"
    }
for i ,(coloumn, title) in enumerate(dict_coloumn.items()):
    ax[i].pie(df_us[coloumn].value_counts(), startangle=90 , autopct='%1.1f%%' , labels = ['False' , 'true'])
    ax[i].set_title(title)
    ax[i].set_xlabel("")
    ax[i].set_ylabel(" ")
    fig.tight_layout()

# %% [markdown]
# Company to explore

# %%
df_us_plot2 = df_us["company_name"].value_counts().head(10)
df_us_plot2 = df_us_plot2.to_frame() #to use seaborn convert to datafrmae
sns.set_theme(style="ticks")
sns.barplot(data=df_us_plot2,x="count",y="company_name",hue="count",palette="dark:b_r",legend=False)
plt.xlabel('No of jobs')
plt.ylabel('')
plt.title('job company count for data analysist in us')
sns.despine() #remove border around graph
