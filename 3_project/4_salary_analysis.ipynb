# %%
# Importing Libraries
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df["job_skills"].apply(lambda Skill_list: ast.literal_eval(Skill_list) if pd.notna(Skill_list) else Skill_list)

# %%
df_us = df[(df['job_country']== "United States")].dropna(subset=['salary_year_avg']) #to plot boxplot dropna value

df_us
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
job_titles= df_us["job_title_short"].value_counts().index[:6].tolist()
job_titles
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Data Engineer',
#  'Senior Data Scientist',
#  'Senior Data Engineer',
#  'Senior Data Analyst']

# %%
df_us_six = df[(df['job_title_short'].isin (job_titles))].copy()
df_us_six
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785731         Data Engineer
# 785732         Data Engineer
# 785735  Senior Data Engineer
# 785737          Data Analyst
# 785739         Data Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785731                                      Data Engineer
# 785732                              Data Engineer (f/m/d)
# 785735                               Senior Data Engineer
# ...

# %%
job_order = df_us_six.groupby("job_title_short")["salary_year_avg"].median().sort_values(ascending=False).index
job_order
# Out:
# Index(['Senior Data Scientist', 'Senior Data Engineer', 'Data Scientist',
#        'Data Engineer', 'Senior Data Analyst', 'Data Analyst'],
#       dtype='object', name='job_title_short')

# %%
sns.boxplot(data=df_us_six,x="salary_year_avg",y="job_title_short",order=job_order)
plt.xlabel('Average Yearly Salary')
plt.title('Distribution of Average Yearly Salary for Different Data Job Titles in the US')
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x , pos: f"${x/1000}k")) # Format y-axis labels as $Xks

# %% [markdown]
# Median salary vs skill for data analyst

# %%
df_usa = df[(df['job_title_short']== "Data Analyst") & (df['job_country']=="United States")].copy()
df_usa
# Out:
#        job_title_short                                     job_title  \
# 36        Data Analyst                                  Data Analyst
# 68        Data Analyst                     Sr. Research Data Analyst
# 73        Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79        Data Analyst                    Data Analyst/Report Writer
# 93        Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# ...                ...                                           ...
# 785603    Data Analyst                           Junior Data Analyst
# 785626    Data Analyst                    Data Acquisition Associate
# 785685    Data Analyst                                  Data Analyst
# 785703    Data Analyst       Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst     Expert Business Data Analyst - Now Hiring
#
#             job_location               job_via job_schedule_type  \
# 36        Des Moines, IA       via Trabajo.org         Full-time
# ...

# %%
df_usa = df_usa.dropna(subset=['salary_year_avg'])
df_usa
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 782637    Data Analyst                     Data Integration Analyst
# 782798    Data Analyst                       Reference Data Analyst
# 783588    Data Analyst                       Data Analytics Manager
# 783866    Data Analyst              Lead Credit Bureau Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
#
#               job_location                job_via job_schedule_type  \
# 109               Anywhere             via Get.It         Full-time
# ...

# %%
df_usa = df_usa.explode("job_skills")
df_usa
# Out:
#        job_title_short                              job_title   job_location  \
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 109       Data Analyst  Senior Supply Chain Analytics Analyst       Anywhere
# 180       Data Analyst                       Data Analyst III  Dos Palos, CA
# ...                ...                                    ...            ...
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
# 784882    Data Analyst   Merchandising Analyst (Data Analyst)     Denton, TX
#
# ...

# %%
df_usa_toppay= df_usa.groupby("job_skills")["salary_year_avg"].agg(["count","median"]).sort_values(by="median",ascending=False)
df_usa_toppay = df_usa_toppay.head(10)
df_usa_toppay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %%
df_usa_topjob =df_usa.groupby("job_skills")["salary_year_avg"].agg(["count","median"]).sort_values(by="count",ascending=False)
df_usa_topjob = df_usa_topjob.head(10).sort_values(by="median",ascending=False)
df_usa_topjob
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
fig , ax = plt.subplots(2,1)
sns.set_theme(style="ticks")
sns.barplot(data=df_usa_topjob,x="median",y=df_usa_topjob.index,ax=ax[0],hue="median",palette="light:b")
sns.barplot(data=df_usa_toppay,x="median",y=df_usa_toppay.index,ax=ax[1],hue="median",palette="dark:b_r")
ax[0].set_title("Top 10 skills by avg salary for data analyst")
ax[1].set_title("Top 10 pay by avg salary for data analyst")
ax[1].legend().remove()
ax[0].set_xlim(ax[1].get_xlim())
ax[0].set_xlabel("")
ax[0].set_ylabel("")
ax[1].set_xlabel("")
ax[1].set_ylabel("")
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x , pos: f"${x/1000}k")) # Format x-axis labels as $Xks
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x , pos: f"${x/1000}k"))
fig.tight_layout()
