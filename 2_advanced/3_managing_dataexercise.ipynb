# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.sample(10)
# Out:
#           job_title_short                                  job_title  \
# 269898      Data Engineer                        Data engineer-(H/F)
# 208563     Data Scientist             Data Scientist Manger, Medical
# 73338       Data Engineer                          Big Data Engineer
# 201751     Cloud Engineer                Storage and backup Engineer
# 620898      Data Engineer                              Data Engineer
# 599102      Data Engineer                       Junior Data Engineer
# 484781       Data Analyst                           Data Analyst F/H
# 126847   Business Analyst                  Business Analyst Power BI
# 376075  Software Engineer  Staff Software Engineer, Machine Learning
# 85099        Data Analyst                               Data Analyst
#
#                             job_location                  job_via  \
# 269898                    Nantes, France             via LinkedIn
# 208563                        Durham, NC                via BeBee
# 73338            New Delhi, Delhi, India             via Bayt.com
# 201751                           Ireland    via My Stateline Jobs
# 620898                    Ghent, Belgium  via Emplois Trabajo.org
# 599102  Hanoi, Hoàn Kiếm, Hanoi, Vietnam      via Việc Làm Hà Nội
# 484781                     Niort, France               via Indeed
# 126847      Dubai - United Arab Emirates          via Trabajo.org
# 376075                         Australia      via BeBee Australia
# 85099            Hauts-de-France, France          via Recruit.net
#
#        job_schedule_type  job_work_from_home         search_location  \
# 269898         Full-time               False                  France
# 208563         Full-time               False  Florida, United States
# 73338          Part-time               False                   India
# 201751        Contractor               False                 Ireland
# 620898         Full-time               False                 Belgium
# 599102         Full-time               False                 Vietnam
# 484781         Full-time               False                  France
# 126847         Full-time               False    United Arab Emirates
# 376075         Full-time               False               Australia
# 85099          Full-time               False                  France
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 269898 2023-06-27 07:50:21                  False                 False
# 208563 2023-12-06 22:03:01                  False                 False
# 73338  2023-05-09 00:16:49                  False                 False
# 201751 2023-02-24 15:57:26                   True                 False
# 620898 2023-12-09 12:45:09                  False                 False
# 599102 2023-06-03 09:12:43                   True                 False
# 484781 2023-08-23 14:16:09                   True                 False
# 126847 2023-03-20 08:30:49                  False                 False
# 376075 2023-10-21 18:11:42                  False                 False
# 85099  2023-01-08 00:15:42                  False                 False
#
#                  job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 269898                France        None              NaN              NaN
# 208563         United States        None              NaN              NaN
# 73338                  India        None              NaN              NaN
# 201751               Ireland        None              NaN              NaN
# 620898               Belgium        None              NaN              NaN
# 599102               Vietnam        None              NaN              NaN
# 484781                France        None              NaN              NaN
# 126847  United Arab Emirates        None              NaN              NaN
# 376075             Australia        None              NaN              NaN
# 85099                 France        None              NaN              NaN
#
#                                            company_name  \
# 269898      Societe Generale Securities Services - SGSS
# 208563                                  GlaxoSmithKline
# 73338                                           Bechtel
# 201751                                            Ateca
# 620898                        Positive Thinking Company
# 599102                                         Crossian
# 484781                                              CGI
# 126847                      Business Incorporation Zone
# 376075  The Allen Institute for Artificial Intelligence
# 85099                                    Web Transition
#
#                                                job_skills  \
# 269898                            ['excel', 'sharepoint']
# 208563                                               None
# 73338   ['python', 'scala', 'sql', 'aws', 'azure', 'da...
# 201751                                               None
# 620898  ['sql', 'scala', 'python', 'azure', 'aws', 'ha...
# 599102  ['postgresql', 'elasticsearch', 'redis', 'aws'...
# 484781  ['python', 'r', 'sas', 'sas', 'sql', 'tableau'...
# 126847                                       ['power bi']
# 376075                 ['c++', 'pytorch', 'wsl', 'slack']
# 85099                   ['sql', 'python', 'r', 'tableau']
#
#                                           job_type_skills
# 269898         {'analyst_tools': ['excel', 'sharepoint']}
# 208563                                               None
# 73338   {'cloud': ['aws', 'azure', 'databricks'], 'lib...
# 201751                                               None
# 620898  {'cloud': ['azure', 'aws'], 'libraries': ['had...
# 599102  {'analyst_tools': ['excel', 'sheets'], 'cloud'...
# 484781  {'analyst_tools': ['sas', 'tableau', 'power bi...
# 126847                    {'analyst_tools': ['power bi']}
# 376075  {'libraries': ['pytorch'], 'os': ['wsl'], 'pro...
# 85099   {'analyst_tools': ['tableau'], 'programming': ...

# %%
df_new = df.copy()

id(df_new) == id(df)
# Out:
# False
